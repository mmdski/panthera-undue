# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from pantherapy.panthera import CrossSection

y = np.array([90, 80, 78, 70, 71, 79, 81, 91])
z = np.array([110, 120, 200, 210, 230, 240, 350, 360])
roughness = 0.013

_ = plt.plot(z, y)
_ = plt.xlabel('z')
_ = plt.ylabel('y')

# %%
xs = CrossSection(y, z, roughness)
wse = np.linspace(y.min(), y.max())

# %%
area = xs.area(wse)

fig, ax = plt.subplots()
fig.set_size_inches((11, 8.5))

_ = ax.plot(wse, area, label='area')
_ = ax.set_xlabel('wse')
_ = ax.set_ylabel('area')

# %%
top_width = xs.top_width(wse)
wetted_perimeter = xs.wetted_perimeter(wse)

fig, ax = plt.subplots()
fig.set_size_inches((11, 8.5))

_ = ax.plot(wse, top_width, label='top width')
_ = ax.plot(wse, wetted_perimeter, label='wetted perimeter')
_ = ax.legend()
_ = ax.set_xlabel('wse')

# %%
hydraulic_depth = xs.hydraulic_depth(wse)
hydraulic_radius = xs.hydraulic_radius(wse)

fig, ax = plt.subplots()
fig.set_size_inches((11, 8.5))

_ = ax.plot(wse, hydraulic_depth, label='hydraulic depth')
_ = ax.plot(wse, hydraulic_radius, label='hydraulic radius')
_ = ax.legend()
_ = ax.set_xlabel('wse')

# %%
xs.conveyance(wse)
# Out:
# array([           nan, 5.31315467e+01, 3.37364293e+02, 1.06217768e+03,
#        2.17492475e+03, 3.59334672e+03, 5.29610765e+03, 7.27094726e+03,
#        9.51068619e+03, 1.20113093e+04, 1.47709078e+04, 1.77890395e+04,
#        2.10663192e+04, 2.46041408e+04, 2.84044855e+04, 3.24697828e+04,
#        3.68028088e+04, 4.14066104e+04, 4.62844476e+04, 4.77410417e+04,
#        4.57398490e+04, 4.74426047e+04, 4.64493530e+04, 5.13210205e+04,
#        6.22744726e+04, 7.69469170e+04, 9.62098226e+04, 1.21792505e+05,
#        1.49724044e+05, 1.79907601e+05, 2.12260506e+05, 2.46711022e+05,
#        2.83196086e+05, 3.21659656e+05, 3.62051487e+05, 4.04326187e+05,
#        4.48442483e+05, 4.94362631e+05, 5.42051954e+05, 5.91478444e+05,
#        6.42612453e+05, 6.95426420e+05, 7.49894649e+05, 8.05993112e+05,
#        8.63699291e+05, 9.22992032e+05, 9.83851420e+05, 1.04678857e+06,
#        1.11236209e+06, 1.17951662e+06])

# %%
xs.conveyance(wse.mean())
# Out:
# 69283.07284086614
